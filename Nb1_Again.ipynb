# %% [markdown]
# <a href="https://colab.research.google.com/github/marilikalantzi/datajour/blob/main/Nb1_Again.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/gdrive/MyDrive/Τελική εργασία σεμινάριο/report.xlsx')
df.head(1)
# Out:
#   type           source                                              title  \
# 0  web  tinealarissa.gr  Καλοκαίρι, παραλία και… Ευρωεκλογές! Ο δήμαρχο...
#
#                                                 text               categories  \
# 0  Summer TV Χώστες Show λίγο μετά τα μεσάνυχτα τ...  ΕΥΡΩΕΚΛΟΓΕΣ - ΕΥΡΩΒΟΥΛΗ
#
#   sentiment  impact        date      time  \
# 0  Positive   90.78  2024-06-08  23:59:52
#
#                                                 link
# 0  https://tinealarissa.gr/2024/06/08/%ce%ba%ce%b...

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df = df.reset_index(drop=True)

# %%
df['date'] = df[['date', 'time']].agg(' '.join, axis=1)

# %%
selected_cols_df = df[["source", "categories", "date", "text"]]
selected_cols_df.head(1)
# Out:
#             source               categories                 date  \
# 0  tinealarissa.gr  ΕΥΡΩΕΚΛΟΓΕΣ - ΕΥΡΩΒΟΥΛΗ  2024-06-08 23:59:52
#
#                                                 text
# 0  Summer TV Χώστες Show λίγο μετά τα μεσάνυχτα τ...

# %%
short_df = selected_cols_df[['date' ,'text']]
short_df.head(1)
# Out:
#                   date                                               text
# 0  2024-06-08 23:59:52  Summer TV Χώστες Show λίγο μετά τα μεσάνυχτα τ...

# %%
short_df.to_csv("/content/gdrive/MyDrive/Τελική εργασία σεμινάριο/report3.csv", index=False)
short_df.tail(1)
# Out:
#                      date                                               text
# 4877  2024-06-07 22:38:58  Την τελευταία δημοσκόπηση πριν το άνοιγμα των ...
